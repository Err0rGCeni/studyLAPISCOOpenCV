# %% [markdown]
# # Hello OpenCV!
# Explorando openCV em Jupyter Notebook

# %% [markdown]
# ## Bibliotecas

# %%
import cv2 #OpenCV
import numpy as np #Arrays
import matplotlib.pyplot as plt #Plots

# %% [markdown]
# ## Carregar Imagem

# %%
img = cv2.imread('../gcPDI/imgPDI/female01.tiff')
type(img)
# Out:
# numpy.ndarray

# %%
img
# Out:
# array([[[ 42,  46,  52],
#         [ 38,  40,  47],
#         [ 34,  42,  50],
#         ...,
#         [136, 131, 137],
#         [136, 137, 126],
#         [130, 134, 126]],
#
#        [[ 43,  45,  55],
#         [ 35,  44,  50],
#         [ 38,  40,  54],
#         ...,
#         [143, 139, 129],
#         [139, 134, 129],
#         [146, 142, 121]],
#
#        [[ 39,  42,  46],
#         [ 43,  42,  49],
#         [ 55,  42,  52],
#         ...,
#         [133, 137, 126],
#         [130, 131, 123],
#         [128, 134, 118]],
#
#        ...,
#
#        [[  5,   5,   4],
#         [  4,   3,   3],
#         [  3,   3,   3],
#         ...,
#         [ 44,  64,  60],
#         [ 91,  93,  84],
#         [ 93, 105,  98]],
#
#        [[ 10,   8,  11],
#         [ 12,  11,  12],
#         [ 10,  10,  12],
#         ...,
#         [ 40,  68,  60],
#         [ 64,  88,  86],
#         [ 91, 105, 100]],
#
#        [[ 16,  18,  20],
#         [ 16,  16,  19],
#         [ 13,  14,  20],
# ...

# %%
img.shape
# Out:
# (256, 256, 3)

# %% [markdown]
# ## Exibição pelo OpenCV (ruim no jupyter lab)

# %%
cv2.imshow('Image', img)
cv2.waitKey(0)
#Melhor usar ESC para evitar bug
cv2.destroyAllWindows()

# %% [markdown]
# ## Exibição pelo Matplotlib (melhor)

# %%
#Imagem sem converter para BGR (openCV)
plt.imshow(img)
plt.show()

# %%
imgRBG = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(imgRBG)
plt.show()

# %%
img = cv2.imread('../imgPDI/female01.tiff', cv2.IMREAD_GRAYSCALE)
img
# Out:
# array([[ 47,  42,  43, ..., 133, 134, 131],
#        [ 48,  45,  44, ..., 136, 133, 136],
#        [ 43,  44,  46, ..., 133, 128, 129],
#        ...,
#        [  5,   3,   3, ...,  61,  90, 102],
#        [  9,  11,  11, ...,  62,  85, 102],
#        [ 18,  17,  16, ...,  54,  73,  96]], dtype=uint8)

# %%
img.shape
# Out:
# (256, 256, 3)

# %%
plt.imshow(img)

# %%
plt.imshow(img, 'gray')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.boxplot()
